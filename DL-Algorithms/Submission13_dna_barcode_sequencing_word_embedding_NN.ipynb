# %%
#Generate vector embedding using tokenizer

# %%
import pandas as pd
import numpy as np
import string
from collections import Counter
from sklearn.model_selection import train_test_split
import csv
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from google.colab import files
import io

# %%
embedding_dim = 100
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"
training_portion = .8

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9c0b23df-52e5-44c8-88d8-e962d8ab4456" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9c0b23df-52e5-44c8-88d8-e962d8ab4456">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test_features.csv to test_features (1).csv
# Saving train_features.csv to train_features (1).csv
# Saving train_labels.csv to train_labels (1).csv

# %%
# turn a seq into clean tokens
def clean_seq(filename):
    seq_df = pd.read_csv(filename)
    sequences = seq_df['dna'].str.replace('[^ACGT]','N')
    for i in range(len(sequences)):
        sequences[i] = sequences[i].ljust(1058,'N')
    sequences_array = np.array(sequences)
    
    seq_list_truncated = []
    for i in range(len(sequences_array)):
        list_seq = list(sequences_array[i])
        del list_seq[650:]
        seq_list_truncated.append(''.join(list_seq))
    
    #print(np.array(seq_list_truncated).shape)
    
    token_list = []
    
    for i in range(len(seq_list_truncated)):
        List = [seq_list_truncated[i][m:m+4] for m in range(len(seq_list_truncated[i])-3)]
        token_list.append(List)
        
    return token_list

# load sequences and create token list
filename = "train_features.csv"
token_list = clean_seq(filename)

def load_labels(filename):
    df = pd.read_csv(filename)
    labels = df['labels']
    return labels

#load labels
filename = 'train_labels.csv'
labels = load_labels(filename)
softmax_layer = len(set(labels))

# %%
train_size = int(len(token_list) * training_portion)

train_seqs = token_list[:train_size]
train_labels = labels[:train_size]

validation_seqs = token_list[train_size:]
validation_labels = labels[train_size:]

# %%
print(np.array(token_list).shape)

print("Number of Unique label Ids:", len(set(labels)))
print(train_size)
print(train_seqs[0])
print(train_seqs[1])
print(train_seqs[10])
print(len(train_labels))
print(len(validation_seqs))
print(len(validation_labels))
# Out:
# (12906, 647)
# Number of Unique label Ids: 1202
# 10324
# ['AACA', 'ACAT', 'CATT', 'ATTA', 'TTAT', 'TATA', 'ATAC', 'TACT', 'ACTT', 'CTTT', 'TTTA', 'TTAT', 'TATT', 'ATTT', 'TTTT', 'TTTC', 'TTCG', 'TCGG', 'CGGA', 'GGAG', 'GAGC', 'AGCA', 'GCAT', 'CATG', 'ATGA', 'TGAT', 'GATC', 'ATCA', 'TCAG', 'CAGG', 'AGGA', 'GGAA', 'GAAT', 'AATA', 'ATAG', 'TAGT', 'AGTA', 'GTAG', 'TAGG', 'AGGA', 'GGAA', 'GAAC', 'AACT', 'ACTT', 'CTTC', 'TTCA', 'TCAT', 'CATT', 'ATTA', 'TTAA', 'TAAG', 'AAGT', 'AGTA', 'GTAT', 'TATA', 'ATAT', 'TATT', 'ATTA', 'TTAA', 'TAAT', 'AATT', 'ATTC', 'TTCG', 'TCGA', 'CGAG', 'GAGC', 'AGCT', 'GCTG', 'CTGA', 'TGAA', 'GAAC', 'AACT', 'ACTA', 'CTAG', 'TAGG', 'AGGA', 'GGAA', 'GAAA', 'AAAT', 'AATC', 'ATCC', 'TCCT', 'CCTG', 'CTGG', 'TGGA', 'GGAG', 'GAGC', 'AGCA', 'GCAT', 'CATT', 'ATTA', 'TTAA', 'TAAT', 'AATT', 'ATTG', 'TTGG', 'TGGA', 'GGAG', 'GAGA', 'AGAT', 'GATG', 'ATGA', 'TGAC', 'GACC', 'ACCA', 'CCAA', 'CAAA', 'AAAT', 'AATT', 'ATTT', 'TTTA', 'TTAT', 'TATA', 'ATAA', 'TAAT', 'AATG', 'ATGT', 'TGTA', 'GTAA', 'TAAT', 'AATT', 'ATTG', 'TTGT', 'TGTA', 'GTAA', 'TAAC', 'AACT', 'ACTG', 'CTGC', 'TGCC', 'GCCC', 'CCCA', 'CCAT', 'CATG', 'ATGC', 'TGCA', 'GCAT', 'CATT', 'ATTT', 'TTTA', 'TTAT', 'TATT', 'ATTA', 'TTAT', 'TATA', 'ATAA', 'TAAT', 'AATT', 'ATTT', 'TTTT', 'TTTC', 'TTCT', 'TCTT', 'CTTT', 'TTTA', 'TTAT', 'TATA', 'ATAG', 'TAGT', 'AGTC', 'GTCA', 'TCAT', 'CATA', 'ATAC', 'TACC', 'ACCT', 'CCTA', 'CTAT', 'TATT', 'ATTA', 'TTAT', 'TATA', 'ATAA', 'TAAT', 'AATT', 'ATTG', 'TTGG', 'TGGA', 'GGAG', 'GAGG', 'AGGA', 'GGAT', 'GATT', 'ATTT', 'TTTG', 'TTGG', 'TGGA', 'GGAA', 'GAAA', 'AAAT', 'AATT', 'ATTG', 'TTGA', 'TGAT', 'GATT', 'ATTA', 'TTAG', 'TAGT', 'AGTC', 'GTCC', 'TCCC', 'CCCT', 'CCTT', 'CTTT', 'TTTA', 'TTAA', 'TAAT', 'AATA', 'ATAT', 'TATT', 'ATTA', 'TTAG', 'TAGG', 'AGGA', 'GGAG', 'GAGC', 'AGCC', 'GCCC', 'CCCC', 'CCCT', 'CCTG', 'CTGA', 'TGAT', 'GATA', 'ATAT', 'TATA', 'ATAG', 'TAGC', 'AGCT', 'GCTT', 'CTTT', 'TTTC', 'TTCC', 'TCCC', 'CCCT', 'CCTC', 'CTCG', 'TCGA', 'CGAA', 'GAAT', 'AATA', 'ATAA', 'TAAA', 'AAAT', 'AATA', 'ATAA', 'TAAT', 'AATA', 'ATAT', 'TATA', 'ATAA', 'TAAG', 'AAGT', 'AGTT', 'GTTT', 'TTTT', 'TTTT', 'TTTG', 'TTGA', 'TGAC', 'GACT', 'ACTA', 'CTAT', 'TATT', 'ATTA', 'TTAC', 'TACC', 'ACCT', 'CCTC', 'CTCC', 'TCCA', 'CCAT', 'CATC', 'ATCT', 'TCTT', 'CTTT', 'TTTA', 'TTAA', 'TAAC', 'AACA', 'ACAT', 'CATT', 'ATTA', 'TTAC', 'TACT', 'ACTT', 'CTTT', 'TTTT', 'TTTA', 'TTAA', 'TAAT', 'AATG', 'ATGA', 'TGAG', 'GAGA', 'AGAA', 'GAAG', 'AAGT', 'AGTA', 'GTAT', 'TATA', 'ATAG', 'TAGT', 'AGTA', 'GTAG', 'TAGA', 'AGAA', 'GAAA', 'AAAG', 'AAGA', 'AGAG', 'GAGG', 'AGGA', 'GGAG', 'GAGC', 'AGCA', 'GCAG', 'CAGG', 'AGGA', 'GGAA', 'GAAC', 'AACT', 'ACTG', 'CTGG', 'TGGA', 'GGAT', 'GATG', 'ATGA', 'TGAA', 'GAAC', 'AACA', 'ACAG', 'CAGT', 'AGTC', 'GTCT', 'TCTA', 'CTAC', 'TACC', 'ACCC', 'CCCA', 'CCAC', 'CACC', 'ACCT', 'CCTT', 'CTTT', 'TTTA', 'TTAT', 'TATC', 'ATCA', 'TCAT', 'CATC', 'ATCT', 'TCTG', 'CTGG', 'TGGT', 'GGTA', 'GTAT', 'TATT', 'ATTG', 'TTGC', 'TGCA', 'GCAC', 'CACA', 'ACAT', 'CATG', 'ATGC', 'TGCA', 'GCAG', 'CAGG', 'AGGA', 'GGAG', 'GAGC', 'AGCT', 'GCTT', 'CTTC', 'TTCA', 'TCAG', 'CAGT', 'AGTT', 'GTTG', 'TTGA', 'TGAT', 'GATT', 'ATTT', 'TTTA', 'TTAG', 'TAGC', 'AGCA', 'GCAA', 'CAAT', 'AATT', 'ATTT', 'TTTT', 'TTTT', 'TTTA', 'TTAG', 'TAGT', 'AGTC', 'GTCT', 'TCTT', 'CTTC', 'TTCA', 'TCAT', 'CATT', 'ATTT', 'TTTA', 'TTAG', 'TAGC', 'AGCT', 'GCTG', 'CTGG', 'TGGA', 'GGAG', 'GAGT', 'AGTT', 'GTTT', 'TTTC', 'TTCA', 'TCAT', 'CATC', 'ATCA', 'TCAA', 'CAAT', 'AATT', 'ATTT', 'TTTT', 'TTTA', 'TTAG', 'TAGG', 'AGGA', 'GGAG', 'GAGC', 'AGCT', 'GCTG', 'CTGT', 'TGTA', 'GTAA', 'TAAA', 'AAAT', 'AATT', 'ATTT', 'TTTT', 'TTTA', 'TTAT', 'TATT', 'ATTA', 'TTAC', 'TACA', 'ACAA', 'CAAC', 'AACA', 'ACAA', 'CAAT', 'AATT', 'ATTA', 'TTAT', 'TATT', 'ATTA', 'TTAA', 'TAAT', 'AATA', 'ATAT', 'TATA', 'ATAC', 'TACG', 'ACGA', 'CGAT', 'GATC', 'ATCA', 'TCAG', 'CAGT', 'AGTA', 'GTAG', 'TAGG', 'AGGA', 'GGAA', 'GAAT', 'AATA', 'ATAA', 'TAAC', 'AACA', 'ACAT', 'CATT', 'ATTT', 'TTTG', 'TTGA', 'TGAT', 'GATC', 'ATCG', 'TCGA', 'CGAA', 'GAAT', 'AATA', 'ATAC', 'TACC', 'ACCA', 'CCAT', 'CATT', 'ATTA', 'TTAT', ...
# ['TACA', 'ACAC', 'CACT', 'ACTA', 'CTAT', 'TATA', 'ATAC', 'TACT', 'ACTT', 'CTTC', 'TTCA', 'TCAT', 'CATT', 'ATTT', 'TTTT', 'TTTT', 'TTTG', 'TTGG', 'TGGT', 'GGTG', 'GTGC', 'TGCT', 'GCTT', 'CTTG', 'TTGA', 'TGAG', 'GAGC', 'AGCA', 'GCAG', 'CAGG', 'AGGA', 'GGAA', 'GAAT', 'AATG', 'ATGC', 'TGCT', 'GCTA', 'CTAG', 'TAGG', 'AGGA', 'GGAA', 'GAAC', 'AACA', 'ACAT', 'CATC', 'ATCA', 'TCAT', 'CATT', 'ATTA', 'TTAA', 'TAAG', 'AAGA', 'AGAC', 'GACT', 'ACTA', 'CTAT', 'TATT', 'ATTA', 'TTAA', 'TAAT', 'AATT', 'ATTC', 'TTCG', 'TCGT', 'CGTG', 'GTGC', 'TGCT', 'GCTG', 'CTGA', 'TGAA', 'GAAT', 'AATT', 'ATTA', 'TTAG', 'TAGG', 'AGGT', 'GGTA', 'GTAA', 'TAAC', 'AACC', 'ACCC', 'CCCA', 'CCAG', 'CAGG', 'AGGA', 'GGAT', 'GATC', 'ATCA', 'TCAT', 'CATT', 'ATTA', 'TTAA', 'TAAT', 'AATT', 'ATTG', 'TTGG', 'TGGA', 'GGAA', 'GAAA', 'AAAC', 'AACG', 'ACGA', 'CGAC', 'GACC', 'ACCA', 'CCAA', 'CAAA', 'AAAT', 'AATC', 'ATCT', 'TCTA', 'CTAT', 'TATA', 'ATAA', 'TAAT', 'AATG', 'ATGT', 'TGTT', 'GTTA', 'TTAT', 'TATT', 'ATTG', 'TTGT', 'TGTA', 'GTAA', 'TAAC', 'AACA', 'ACAG', 'CAGC', 'AGCA', 'GCAC', 'CACA', 'ACAT', 'CATG', 'ATGC', 'TGCA', 'GCAT', 'CATT', 'ATTT', 'TTTA', 'TTAT', 'TATT', 'ATTA', 'TTAT', 'TATA', 'ATAA', 'TAAT', 'AATT', 'ATTT', 'TTTT', 'TTTC', 'TTCT', 'TCTT', 'CTTT', 'TTTA', 'TTAT', 'TATA', 'ATAG', 'TAGT', 'AGTT', 'GTTA', 'TTAT', 'TATA', 'ATAC', 'TACC', 'ACCT', 'CCTA', 'CTAT', 'TATC', 'ATCA', 'TCAT', 'CATA', 'ATAA', 'TAAT', 'AATT', 'ATTG', 'TTGG', 'TGGG', 'GGGG', 'GGGG', 'GGGA', 'GGAT', 'GATT', 'ATTT', 'TTTG', 'TTGG', 'TGGT', 'GGTA', 'GTAA', 'TAAC', 'AACT', 'ACTG', 'CTGA', 'TGAC', 'GACT', 'ACTA', 'CTAG', 'TAGT', 'AGTT', 'GTTC', 'TTCC', 'TCCA', 'CCAT', 'CATT', 'ATTA', 'TTAA', 'TAAT', 'AATA', 'ATAC', 'TACT', 'ACTA', 'CTAG', 'TAGG', 'AGGA', 'GGAG', 'GAGC', 'AGCC', 'GCCC', 'CCCC', 'CCCA', 'CCAG', 'CAGA', 'AGAT', 'GATA', 'ATAT', 'TATA', 'ATAG', 'TAGC', 'AGCA', 'GCAT', 'CATT', 'ATTT', 'TTTC', 'TTCC', 'TCCA', 'CCAC', 'CACG', 'ACGA', 'CGAA', 'GAAT', 'AATA', 'ATAA', 'TAAA', 'AAAT', 'AATA', 'ATAA', 'TAAC', 'AACA', 'ACAT', 'CATA', 'ATAA', 'TAAG', 'AAGA', 'AGAT', 'GATT', 'ATTC', 'TTCT', 'TCTG', 'CTGA', 'TGAT', 'GATT', 'ATTT', 'TTTC', 'TTCT', 'TCTC', 'CTCC', 'TCCC', 'CCCT', 'CCTC', 'CTCC', 'TCCT', 'CCTT', 'CTTC', 'TTCA', 'TCAT', 'CATT', 'ATTA', 'TTAT', 'TATC', 'ATCC', 'TCCC', 'CCCT', 'CCTT', 'CTTC', 'TTCT', 'TCTC', 'CTCC', 'TCCT', 'CCTA', 'CTAA', 'TAAT', 'AATA', 'ATAA', 'TAAG', 'AAGA', 'AGAA', 'GAAG', 'AAGA', 'AGAA', 'GAAT', 'AATT', 'ATTG', 'TTGT', 'TGTA', 'GTAG', 'TAGA', 'AGAA', 'GAAA', 'AAAA', 'AAAT', 'AATG', 'ATGG', 'TGGA', 'GGAG', 'GAGC', 'AGCA', 'GCAG', 'CAGG', 'AGGA', 'GGAA', 'GAAC', 'AACA', 'ACAG', 'CAGG', 'AGGT', 'GGTT', 'GTTG', 'TTGA', 'TGAA', 'GAAC', 'AACA', 'ACAG', 'CAGT', 'AGTT', 'GTTT', 'TTTA', 'TTAC', 'TACC', 'ACCC', 'CCCT', 'CCTC', 'CTCC', 'TCCC', 'CCCT', 'CCTT', 'CTTA', 'TTAT', 'TATC', 'ATCA', 'TCAG', 'CAGC', 'AGCA', 'GCAA', 'CAAA', 'AAAT', 'AATA', 'ATAT', 'TATT', 'ATTG', 'TTGC', 'TGCT', 'GCTC', 'CTCA', 'TCAT', 'CATA', 'ATAG', 'TAGA', 'AGAG', 'GAGG', 'AGGA', 'GGAT', 'GATC', 'ATCA', 'TCAT', 'CATC', 'ATCA', 'TCAG', 'CAGT', 'AGTT', 'GTTG', 'TTGA', 'TGAT', 'GATC', 'ATCT', 'TCTA', 'CTAG', 'TAGC', 'AGCA', 'GCAA', 'CAAT', 'AATT', 'ATTT', 'TTTT', 'TTTT', 'TTTA', 'TTAG', 'TAGT', 'AGTT', 'GTTT', 'TTTA', 'TTAC', 'TACA', 'ACAT', 'CATC', 'ATCT', 'TCTA', 'CTAG', 'TAGC', 'AGCA', 'GCAG', 'CAGG', 'AGGA', 'GGAA', 'GAAT', 'AATT', 'ATTT', 'TTTC', 'TTCA', 'TCAT', 'CATC', 'ATCC', 'TCCA', 'CCAT', 'CATC', 'ATCC', 'TCCT', 'CCTT', 'CTTG', 'TTGG', 'TGGA', 'GGAG', 'GAGC', 'AGCC', 'GCCG', 'CCGT', 'CGTA', 'GTAA', 'TAAA', 'AAAT', 'AATT', 'ATTT', 'TTTT', 'TTTA', 'TTAT', 'TATT', 'ATTT', 'TTTC', 'TTCA', 'TCAA', 'CAAC', 'AACA', 'ACAG', 'CAGT', 'AGTA', 'GTAA', 'TAAT', 'AATC', 'ATCA', 'TCAA', 'CAAT', 'AATA', 'ATAT', 'TATA', 'ATAC', 'TACG', 'ACGA', 'CGAT', 'GATC', 'ATCA', 'TCAA', 'CAAC', 'AACT', 'ACTG', 'CTGG', 'TGGA', 'GGAA', 'GAAT', 'AATC', 'ATCA', 'TCAC', 'CACA', 'ACAT', 'CATT', 'ATTT', 'TTTG', 'TTGA', 'TGAC', 'GACC', 'ACCG', 'CCGA', 'CGAA', 'GAAT', 'AATA', 'ATAC', 'TACC', 'ACCT', 'CCTC', 'CTCT', 'TCTA', 'CTAT', ...
# ['AACT', 'ACTC', 'CTCT', 'TCTT', 'CTTT', 'TTTA', 'TTAC', 'TACT', 'ACTT', 'CTTT', 'TTTT', 'TTTT', 'TTTA', 'TTAT', 'TATT', 'ATTC', 'TTCG', 'TCGG', 'CGGG', 'GGGA', 'GGAG', 'GAGT', 'AGTT', 'GTTG', 'TTGG', 'TGGG', 'GGGC', 'GGCA', 'GCAG', 'CAGG', 'AGGA', 'GGAA', 'GAAT', 'AATA', 'ATAG', 'TAGT', 'AGTA', 'GTAG', 'TAGG', 'AGGT', 'GGTA', 'GTAC', 'TACA', 'ACAT', 'CATC', 'ATCA', 'TCAT', 'CATT', 'ATTA', 'TTAA', 'TAAG', 'AAGA', 'AGAC', 'GACT', 'ACTA', 'CTAT', 'TATT', 'ATTA', 'TTAA', 'TAAT', 'AATT', 'ATTC', 'TTCG', 'TCGA', 'CGAG', 'GAGC', 'AGCC', 'GCCG', 'CCGA', 'CGAA', 'GAAT', 'AATT', 'ATTA', 'TTAG', 'TAGG', 'AGGA', 'GGAA', 'GAAA', 'AAAC', 'AACC', 'ACCC', 'CCCT', 'CCTG', 'CTGG', 'TGGA', 'GGAT', 'GATC', 'ATCT', 'TCTT', 'CTTT', 'TTTA', 'TTAA', 'TAAT', 'AATT', 'ATTG', 'TTGG', 'TGGA', 'GGAG', 'GAGA', 'AGAT', 'GATG', 'ATGA', 'TGAT', 'GATC', 'ATCA', 'TCAA', 'CAAA', 'AAAT', 'AATT', 'ATTT', 'TTTA', 'TTAT', 'TATA', 'ATAA', 'TAAT', 'AATG', 'ATGT', 'TGTA', 'GTAA', 'TAAT', 'AATT', 'ATTG', 'TTGT', 'TGTA', 'GTAA', 'TAAC', 'AACT', 'ACTG', 'CTGC', 'TGCC', 'GCCC', 'CCCA', 'CCAT', 'CATG', 'ATGC', 'TGCA', 'GCAT', 'CATT', 'ATTT', 'TTTG', 'TTGT', 'TGTA', 'GTAA', 'TAAT', 'AATA', 'ATAA', 'TAAT', 'AATT', 'ATTT', 'TTTT', 'TTTT', 'TTTT', 'TTTT', 'TTTT', 'TTTA', 'TTAT', 'TATA', 'ATAG', 'TAGT', 'AGTT', 'GTTA', 'TTAT', 'TATA', 'ATAC', 'TACC', 'ACCT', 'CCTA', 'CTAT', 'TATT', 'ATTT', 'TTTT', 'TTTA', 'TTAA', 'TAAT', 'AATT', 'ATTG', 'TTGG', 'TGGG', 'GGGG', 'GGGG', 'GGGA', 'GGAT', 'GATT', 'ATTC', 'TTCG', 'TCGG', 'CGGA', 'GGAA', 'GAAA', 'AAAT', 'AATT', 'ATTG', 'TTGA', 'TGAC', 'GACT', 'ACTA', 'CTAG', 'TAGT', 'AGTC', 'GTCC', 'TCCC', 'CCCA', 'CCAC', 'CACT', 'ACTA', 'CTAA', 'TAAT', 'AATA', 'ATAC', 'TACT', 'ACTA', 'CTAG', 'TAGG', 'AGGG', 'GGGG', 'GGGC', 'GGCC', 'GCCC', 'CCCC', 'CCCA', 'CCAG', 'CAGA', 'AGAT', 'GATA', 'ATAT', 'TATG', 'ATGG', 'TGGC', 'GGCA', 'GCAT', 'CATT', 'ATTC', 'TTCC', 'TCCC', 'CCCA', 'CCAC', 'CACG', 'ACGA', 'CGAA', 'GAAT', 'AATA', 'ATAA', 'TAAA', 'AAAT', 'AATA', 'ATAA', 'TAAT', 'AATA', 'ATAT', 'TATA', 'ATAA', 'TAAG', 'AAGA', 'AGAT', 'GATT', 'ATTT', 'TTTT', 'TTTG', 'TTGA', 'TGAC', 'GACT', 'ACTT', 'CTTC', 'TTCT', 'TCTT', 'CTTC', 'TTCC', 'TCCT', 'CCTC', 'CTCC', 'TCCT', 'CCTT', 'CTTC', 'TTCA', 'TCAC', 'CACT', 'ACTA', 'CTAA', 'TAAC', 'AACT', 'ACTT', 'CTTT', 'TTTG', 'TTGT', 'TGTT', 'GTTA', 'TTAC', 'TACT', 'ACTA', 'CTAA', 'TAAT', 'AATA', 'ATAA', 'TAAG', 'AAGA', 'AGAA', 'GAAG', 'AAGA', 'AGAA', 'GAAT', 'AATA', 'ATAG', 'TAGT', 'AGTA', 'GTAG', 'TAGA', 'AGAA', 'GAAA', 'AAAG', 'AAGA', 'AGAG', 'GAGG', 'AGGG', 'GGGG', 'GGGC', 'GGCT', 'GCTG', 'CTGG', 'TGGA', 'GGAA', 'GAAC', 'AACT', 'ACTG', 'CTGG', 'TGGT', 'GGTT', 'GTTG', 'TTGA', 'TGAA', 'GAAC', 'AACG', 'ACGG', 'CGGT', 'GGTA', 'GTAT', 'TATA', 'ATAC', 'TACC', 'ACCC', 'CCCG', 'CCGC', 'CGCC', 'GCCT', 'CCTC', 'CTCT', 'TCTA', 'CTAT', 'TATC', 'ATCA', 'TCAT', 'CATC', 'ATCT', 'TCTA', 'CTAA', 'TAAT', 'AATA', 'ATAT', 'TATT', 'ATTG', 'TTGC', 'TGCT', 'GCTC', 'CTCA', 'TCAT', 'CATG', 'ATGG', 'TGGA', 'GGAG', 'GAGG', 'AGGA', 'GGAG', 'GAGC', 'AGCA', 'GCAT', 'CATC', 'ATCT', 'TCTG', 'CTGT', 'TGTT', 'GTTG', 'TTGA', 'TGAT', 'GATT', 'ATTT', 'TTTA', 'TTAG', 'TAGC', 'AGCT', 'GCTA', 'CTAT', 'TATT', 'ATTT', 'TTTT', 'TTTT', 'TTTA', 'TTAG', 'TAGA', 'AGAT', 'GATT', 'ATTA', 'TTAC', 'TACA', 'ACAT', 'CATC', 'ATCT', 'TCTT', 'CTTG', 'TTGC', 'TGCC', 'GCCG', 'CCGG', 'CGGA', 'GGAA', 'GAAT', 'AATC', 'ATCT', 'TCTC', 'CTCC', 'TCCT', 'CCTC', 'CTCA', 'TCAA', 'CAAT', 'AATT', 'ATTT', 'TTTT', 'TTTA', 'TTAG', 'TAGG', 'AGGA', 'GGAG', 'GAGC', 'AGCT', 'GCTG', 'CTGT', 'TGTA', 'GTAA', 'TAAA', 'AAAT', 'AATT', 'ATTT', 'TTTT', 'TTTA', 'TTAT', 'TATT', 'ATTA', 'TTAC', 'TACC', 'ACCA', 'CCAC', 'CACT', 'ACTG', 'CTGT', 'TGTA', 'GTAA', 'TAAT', 'AATT', 'ATTA', 'TTAA', 'TAAT', 'AATA', 'ATAT', 'TATA', 'ATAC', 'TACG', 'ACGA', 'CGAT', 'GATC', 'ATCC', 'TCCC', 'CCCC', 'CCCA', 'CCAG', 'CAGG', 'AGGA', 'GGAA', 'GAAT', 'AATA', 'ATAA', 'TAAC', 'AACT', 'ACTT', 'CTTT', 'TTTT', 'TTTG', 'TTGA', 'TGAT', 'GATC', 'ATCG', 'TCGA', 'CGAA', 'GAAT', 'AATA', 'ATAC', 'TACC', 'ACCT', 'CCTT', 'CTTT', 'TTTA', 'TTAT', ...
# 10324
# 2582
# 2582

# %%
tokenizer = Tokenizer(oov_token=oov_tok)
tokenizer.fit_on_texts(train_seqs)
word_index = tokenizer.word_index

vocab_size = len(word_index) + 1

train_sequences = tokenizer.texts_to_sequences(train_seqs)
train_padded = pad_sequences(train_sequences, padding=padding_type)

max_length = len(train_padded[0])

print(train_padded.shape)

print(len(train_sequences[0]))
print(len(train_padded[0]))

print(len(train_sequences[1]))
print(len(train_padded[1]))

print(len(train_sequences[10]))
print(len(train_padded[10]))
# Out:
# (10324, 647)
# 647
# 647
# 647
# 647
# 647
# 647

# %%
validation_sequences = tokenizer.texts_to_sequences(validation_seqs)
validation_padded = pad_sequences(validation_sequences, padding=padding_type, maxlen=max_length)

print(len(validation_sequences))
print(validation_padded.shape)
# Out:
# 2582
# (2582, 647)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(labels)
label_seq = le.transform(labels)

output = []
for v in label_seq:
    output.append([v])

print(output)
training_label_seq = np.array(output[:train_size])
validation_label_seq = np.array(output[train_size:])
# Out:
# [[31], [626], [1163], [30], [461], [450], [1164], [853], [626], [553], [780], [722], [643], [895], [44], [216], [364], [358], [1115], [1055], [384], [1012], [473], [372], [198], [858], [786], [248], [505], [220], [1085], [331], [647], [998], [1185], [714], [900], [152], [10], [614], [372], [370], [507], [321], [1099], [114], [213], [982], [15], [929], [734], [424], [540], [176], [226], [1161], [396], [550], [284], [680], [205], [586], [16], [462], [905], [372], [747], [1148], [641], [53], [822], [1035], [1054], [30], [673], [92], [1150], [461], [514], [959], [366], [444], [871], [848], [391], [1083], [4], [1176], [311], [881], [568], [513], [677], [11], [757], [1142], [997], [1166], [995], [747], [1162], [664], [32], [747], [643], [409], [734], [677], [67], [195], [599], [799], [416], [750], [877], [118], [793], [572], [532], [210], [555], [83], [617], [853], [479], [328], [693], [1200], [1200], [308], [584], [1150], [1172], [556], [468], [380], [524], [835], [686], [553], [809], [105], [322], [166], [249], [1103], [778], [1070], [934], [730], [358], [330], [426], [717], [244], [219], [678], [1118], [387], [361], [104], [680], [726], [508], [458], [387], [492], [352], [146], [1078], [76], [617], [979], [1181], [826], [293], [846], [1166], [303], [831], [402], [148], [249], [382], [1026], [835], [804], [1045], [550], [929], [617], [915], [1072], [1172], [956], [594], [167], [769], [945], [985], [68], [660], [1119], [68], [52], [1185], [599], [1041], [967], [659], [1199], [346], [116], [1165], [820], [251], [346], [395], [277], [193], [401], [1178], [84], [887], [1183], [736], [401], [888], [201], [848], [281], [521], [981], [236], [1135], [70], [941], [743], [147], [952], [732], [1030], [710], [582], [329], [862], [811], [276], [332], [1066], [537], [640], [507], [192], [390], [283], [1082], [10], [210], [861], [1071], [1020], [802], [873], [1150], [1025], [381], [264], [1182], [961], [524], [884], [445], [390], [492], [1155], [1095], [168], [110], [118], [433], [416], [445], [882], [563], [504], [409], [683], [274], [39], [1170], [367], [349], [1104], [687], [533], [1069], [556], [317], [400], [359], [750], [371], [554], [1010], [1027], [478], [500], [821], [135], [1109], [1050], [937], [708], [609], [313], [598], [412], [347], [261], [918], [425], [787], [249], [203], [269], [555], [479], [278], [211], [102], [175], [776], [788], [858], [480], [732], [322], [142], [690], [126], [8], [49], [18], [543], [444], [595], [1155], [921], [1065], [804], [385], [484], [1051], [701], [57], [485], [1155], [1174], [642], [646], [1050], [398], [371], [333], [914], [331], [933], [367], [471], [403], [860], [368], [48], [868], [188], [215], [730], [877], [390], [893], [193], [598], [224], [35], [624], [207], [192], [349], [398], [526], [645], [118], [94], [980], [732], [372], [503], [963], [889], [159], [130], [248], [1181], [1015], [590], [164], [739], [729], [502], [1200], [1148], [104], [876], [76], [290], [416], [531], [505], [679], [203], [629], [503], [555], [617], [270], [1201], [531], [1077], [1071], [745], [1096], [224], [302], [1003], [567], [520], [824], [178], [463], [400], [43], [838], [499], [141], [23], [611], [868], [398], [302], [742], [938], [1045], [597], [1050], [308], [346], [1155], [767], [304], [1086], [114], [339], [383], [737], [57], [1144], [362], [421], [680], [514], [492], [1135], [269], [7], [772], [8], [526], [971], [712], [1124], [355], [908], [518], [104], [4], [1179], [83], [708], [184], [1005], [1165], [1013], [1073], [572], [1200], [697], [1022], [1025], [466], [289], [59], [986], [1165], [331], [39], [1143], [1157], [319], [857], [875], [617], [604], [821], [521], [1165], [1166], [456], [1197], [200], [332], [118], [1019], [442], [746], [194], [41], [401], [1118], [574], [613], [372], [783], [881], [443], [881], [157], [460], [1155], [201], [299], [207], [599], [219], [1021], [364], [321], [1161], [295], [681], [892], [936], [598], [696], [281], [676], [693], [930], [486], [339], [680], [428], [860], [798] ...

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(250, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.25), 
    tf.keras.layers.Dense(500, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(softmax_layer, activation='softmax')
])

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 647, 100)          61200
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 647, 100)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 64700)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 100)               6470100
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 100)               400
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 250)               25250
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 250)               1000
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 250)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 500)               125500
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 500)               2000
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1202)              602202
# =================================================================
# Total params: 7,287,652
# Trainable params: 7,285,952
# Non-trainable params: 1,700
# _________________________________________________________________

# %%
num_epochs = 50

# Create a callback that saves the model's weights
#https://jonathan-hui.medium.com/tensorflow-save-restore-model-75a1e6d3b9a6
#https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/ModelCheckpoint
callbacks = [
        tf.keras.callbacks.ModelCheckpoint(
        filepath="mymodel_{epoch}", save_weights_only=True,
        save_best_only = True, monitor = "val_loss", verbose =1,)]

history = model.fit(train_padded, training_label_seq, epochs=num_epochs, callbacks=callbacks, validation_data=(validation_padded, validation_label_seq), verbose=2)
# Out:
# Epoch 1/50
# 323/323 - 3s - loss: 0.2979 - accuracy: 0.9143 - val_loss: 0.2807 - val_accuracy: 0.9597
#
# Epoch 00001: val_loss improved from inf to 0.28069, saving model to mymodel_1
# Epoch 2/50
# 323/323 - 3s - loss: 0.2678 - accuracy: 0.9221 - val_loss: 0.3021 - val_accuracy: 0.9574
#
# Epoch 00002: val_loss did not improve from 0.28069
# Epoch 3/50
# 323/323 - 3s - loss: 0.2678 - accuracy: 0.9243 - val_loss: 0.3094 - val_accuracy: 0.9574
#
# Epoch 00003: val_loss did not improve from 0.28069
# Epoch 4/50
# 323/323 - 3s - loss: 0.2601 - accuracy: 0.9224 - val_loss: 0.3095 - val_accuracy: 0.9593
#
# Epoch 00004: val_loss did not improve from 0.28069
# Epoch 5/50
# 323/323 - 3s - loss: 0.2478 - accuracy: 0.9248 - val_loss: 0.2923 - val_accuracy: 0.9597
#
# Epoch 00005: val_loss did not improve from 0.28069
# Epoch 6/50
# 323/323 - 3s - loss: 0.2404 - accuracy: 0.9292 - val_loss: 0.3254 - val_accuracy: 0.9601
#
# Epoch 00006: val_loss did not improve from 0.28069
# Epoch 7/50
# 323/323 - 3s - loss: 0.2207 - accuracy: 0.9329 - val_loss: 0.2877 - val_accuracy: 0.9644
#
# Epoch 00007: val_loss did not improve from 0.28069
# Epoch 8/50
# 323/323 - 3s - loss: 0.2268 - accuracy: 0.9323 - val_loss: 0.2745 - val_accuracy: 0.9624
#
# Epoch 00008: val_loss improved from 0.28069 to 0.27453, saving model to mymodel_8
# Epoch 9/50
# 323/323 - 3s - loss: 0.2041 - accuracy: 0.9410 - val_loss: 0.2718 - val_accuracy: 0.9636
#
# Epoch 00009: val_loss improved from 0.27453 to 0.27183, saving model to mymodel_9
# Epoch 10/50
# 323/323 - 3s - loss: 0.1912 - accuracy: 0.9425 - val_loss: 0.3037 - val_accuracy: 0.9624
#
# Epoch 00010: val_loss did not improve from 0.27183
# Epoch 11/50
# 323/323 - 3s - loss: 0.2188 - accuracy: 0.9390 - val_loss: 0.2968 - val_accuracy: 0.9617
#
# Epoch 00011: val_loss did not improve from 0.27183
# Epoch 12/50
# 323/323 - 3s - loss: 0.1981 - accuracy: 0.9420 - val_loss: 0.3001 - val_accuracy: 0.9636
#
# Epoch 00012: val_loss did not improve from 0.27183
# Epoch 13/50
# 323/323 - 3s - loss: 0.2002 - accuracy: 0.9421 - val_loss: 0.2930 - val_accuracy: 0.9636
#
# Epoch 00013: val_loss did not improve from 0.27183
# Epoch 14/50
# 323/323 - 3s - loss: 0.1902 - accuracy: 0.9449 - val_loss: 0.2982 - val_accuracy: 0.9632
#
# Epoch 00014: val_loss did not improve from 0.27183
# Epoch 15/50
# 323/323 - 3s - loss: 0.1997 - accuracy: 0.9443 - val_loss: 0.2857 - val_accuracy: 0.9659
#
# Epoch 00015: val_loss did not improve from 0.27183
# Epoch 16/50
# 323/323 - 3s - loss: 0.1891 - accuracy: 0.9448 - val_loss: 0.2947 - val_accuracy: 0.9644
#
# Epoch 00016: val_loss did not improve from 0.27183
# Epoch 17/50
# 323/323 - 3s - loss: 0.1865 - accuracy: 0.9460 - val_loss: 0.3116 - val_accuracy: 0.9644
#
# Epoch 00017: val_loss did not improve from 0.27183
# Epoch 18/50
# 323/323 - 3s - loss: 0.1692 - accuracy: 0.9514 - val_loss: 0.3235 - val_accuracy: 0.9640
#
# Epoch 00018: val_loss did not improve from 0.27183
# Epoch 19/50
# 323/323 - 3s - loss: 0.1714 - accuracy: 0.9522 - val_loss: 0.3005 - val_accuracy: 0.9648
#
# Epoch 00019: val_loss did not improve from 0.27183
# Epoch 20/50
# 323/323 - 3s - loss: 0.1667 - accuracy: 0.9512 - val_loss: 0.2960 - val_accuracy: 0.9659
#
# Epoch 00020: val_loss did not improve from 0.27183
# Epoch 21/50
# 323/323 - 3s - loss: 0.1561 - accuracy: 0.9524 - val_loss: 0.2703 - val_accuracy: 0.9682
#
# Epoch 00021: val_loss improved from 0.27183 to 0.27029, saving model to mymodel_21
# Epoch 22/50
# 323/323 - 3s - loss: 0.1570 - accuracy: 0.9549 - val_loss: 0.3201 - val_accuracy: 0.9655
#
# Epoch 00022: val_loss did not improve from 0.27029
# Epoch 23/50
# 323/323 - 3s - loss: 0.1475 - accuracy: 0.9573 - val_loss: 0.3003 - val_accuracy: 0.9659
#
# Epoch 00023: val_loss did not improve from 0.27029
# Epoch 24/50
# 323/323 - 3s - loss: 0.1510 - accuracy: 0.9546 - val_loss: 0.3081 - val_accuracy: 0.9651
#
# Epoch 00024: val_loss did not improve from 0.27029
# Epoch 25/50
# 323/323 - 3s - loss: 0.1464 - accuracy: 0.9546 - val_loss: 0.3167 - val_accuracy: 0.9655
#
# Epoch 00025: val_loss did not improve from 0.27029
# Epoch 26/50
# 323/323 - 3s - loss: 0.1434 - accuracy: 0.9562 - val_loss: 0.2873 - val_accuracy: 0.9659
#
# Epoch 00026: val_loss did not improve from 0.27029
# Epoch 27/50
# 323/323 - 3s - loss: 0.1474 - accuracy: 0.9552 - val_loss: 0.3090 - val_accuracy: 0.9667
#
# Epoch 00027: val_loss did not improve from 0.27029
# Epoch 28/50
# 323/323 - 3s - loss: 0.1467 - accuracy: 0.9569 - val_loss: 0.3181 - val_accuracy: 0.9648
#
# Epoch 00028: val_loss did not improve from 0.27029
# Epoch 29/50
# 323/323 - 3s - loss: 0.1474 - accuracy: 0.9568 - val_loss: 0.3217 - val_accuracy: 0.9640
#
# Epoch 00029: val_loss did not improve from 0.27029
# Epoch 30/50
# 323/323 - 3s - loss: 0.1337 - accuracy: 0.9601 - val_loss: 0.3316 - val_accuracy: 0.9667
#
# Epoch 00030: val_loss did not improve from 0.27029
# Epoch 31/50
# 323/323 - 3s - loss: 0.1410 - accuracy: 0.9596 - val_loss: 0.3207 - val_accuracy: 0.9655
#
# Epoch 00031: val_loss did not improve from 0.27029
# Epoch 32/50
# 323/323 - 3s - loss: 0.1380 - accuracy: 0.9586 - val_loss: 0.2866 - val_accuracy: 0.9679
#
# Epoch 00032: val_loss did not improve from 0.27029
# Epoch 33/50
# 323/323 - 3s - loss: 0.1320 - accuracy: 0.9625 - val_loss: 0.3069 - val_accuracy: 0.9682
#
# Epoch 00033: val_loss did not improve from 0.27029
# Epoch 34/50
# 323/323 - 3s - loss: 0.1241 - accuracy: 0.9631 - val_loss: 0.2968 - val_accuracy: 0.9675
#
# Epoch 00034: val_loss did not improve from 0.27029
# Epoch 35/50
# 323/323 - 3s - loss: 0.1191 - accuracy: 0.9648 - val_loss: 0.3171 - val_accuracy: 0.9675
#
# Epoch 00035: val_loss did not improve from 0.27029
# Epoch 36/50
# 323/323 - 3s - loss: 0.1326 - accuracy: 0.9638 - val_loss: 0.3286 - val_accuracy: 0.9679
#
# Epoch 00036: val_loss did not improve from 0.27029
# Epoch 37/50
# 323/323 - 3s - loss: 0.1186 - accuracy: 0.9623 - val_loss: 0.3480 - val_accuracy: 0.9682
#
# Epoch 00037: val_loss did not improve from 0.27029
# Epoch 38/50
# 323/323 - 3s - loss: 0.1121 - accuracy: 0.9661 - val_loss: 0.3323 - val_accuracy: 0.9651
#
# Epoch 00038: val_loss did not improve from 0.27029
# Epoch 39/50
# 323/323 - 3s - loss: 0.1244 - accuracy: 0.9645 - val_loss: 0.3351 - val_accuracy: 0.9648
#
# Epoch 00039: val_loss did not improve from 0.27029
# Epoch 40/50
# 323/323 - 3s - loss: 0.1133 - accuracy: 0.9673 - val_loss: 0.3237 - val_accuracy: 0.9648
#
# Epoch 00040: val_loss did not improve from 0.27029
# Epoch 41/50
# 323/323 - 3s - loss: 0.1167 - accuracy: 0.9677 - val_loss: 0.3314 - val_accuracy: 0.9675
#
# Epoch 00041: val_loss did not improve from 0.27029
# Epoch 42/50
# 323/323 - 3s - loss: 0.1127 - accuracy: 0.9671 - val_loss: 0.3206 - val_accuracy: 0.9675
#
# Epoch 00042: val_loss did not improve from 0.27029
# Epoch 43/50
# 323/323 - 3s - loss: 0.1154 - accuracy: 0.9641 - val_loss: 0.3632 - val_accuracy: 0.9651
#
# Epoch 00043: val_loss did not improve from 0.27029
# Epoch 44/50
# 323/323 - 3s - loss: 0.1163 - accuracy: 0.9674 - val_loss: 0.3436 - val_accuracy: 0.9663
#
# Epoch 00044: val_loss did not improve from 0.27029
# Epoch 45/50
# 323/323 - 3s - loss: 0.1117 - accuracy: 0.9672 - val_loss: 0.3338 - val_accuracy: 0.9663
#
# Epoch 00045: val_loss did not improve from 0.27029
# Epoch 46/50
# 323/323 - 3s - loss: 0.1109 - accuracy: 0.9654 - val_loss: 0.3533 - val_accuracy: 0.9671
#
# Epoch 00046: val_loss did not improve from 0.27029
# Epoch 47/50
# 323/323 - 3s - loss: 0.1184 - accuracy: 0.9648 - val_loss: 0.3404 - val_accuracy: 0.9644
#
# Epoch 00047: val_loss did not improve from 0.27029
# Epoch 48/50
# 323/323 - 3s - loss: 0.0935 - accuracy: 0.9736 - val_loss: 0.3331 - val_accuracy: 0.9675
#
# Epoch 00048: val_loss did not improve from 0.27029
# Epoch 49/50
# 323/323 - 3s - loss: 0.0772 - accuracy: 0.9780 - val_loss: 0.3437 - val_accuracy: 0.9671
#
# Epoch 00049: val_loss did not improve from 0.27029
# Epoch 50/50
# 323/323 - 3s - loss: 0.1006 - accuracy: 0.9696 - val_loss: 0.3092 - val_accuracy: 0.9690
#
# Epoch 00050: val_loss did not improve from 0.27029

# %%
import matplotlib.pyplot as plt

def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()

plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %%
## Test prediction

# %%
filename_features_test = 'test_features.csv'
test_seqs = clean_seq(filename_features_test)
test_sequences = tokenizer.texts_to_sequences(test_seqs)

predictions = np.argmax(model.predict(test_sequences), axis=1)
print(predictions)

def decode_labels(encoded_predict_labels, le):
    test_predictions = le.inverse_transform(encoded_predict_labels)
    
    return test_predictions

test_seq_predictions = decode_labels(predictions, le)
print(test_seq_predictions)
# Out:
# [ 659    7  200 ...  746 1059  590]
# [ 667    8  205 ...  755 1071  597]

# %%
def get_seq_ids(filename):
    df = pd.read_csv(filename)
    ids = df['id']
    
    return np.array(ids)

test_ids = get_seq_ids(filename_features_test)
print(test_ids)

frames = [pd.DataFrame(test_ids), pd.DataFrame(test_seq_predictions)]
output_data= np.concatenate(frames, axis=1)
output_df = pd.DataFrame(output_data)
output_df.to_csv('dna_barcode_seq_submission6_word_embedding_nn.csv', index=False,  header=["id","labels"])
# Out:
# [   1    2    3 ... 8304 8305 8306]

# %%
from google.colab import files
files.download("dna_barcode_seq_submission6_word_embedding_nn.csv")
